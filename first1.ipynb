# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ARITHEMATIC OPERATOR
# 1.ADDITION (+)
# 2.SUBSTRACTION (-)
# 3.MULTIPLICATION (*)
# 4.DIVISION (/)
# 5.FLOOR DIVISION  (//)
# 6.MODULUS (%)
# 7.POWER (**)

# %%
a=3
b=2
c=a+b
print("ADDITION:",c)
c=a-b
print("SUBTRACTION:",c)
c=a*b
print("MULTIPLICATION:",c)
c=a/b
print("DIVISION:",c)
c=a//b
print("FLOOR DIVISION:",c)
c=a%b
print("MODULUS:",c)
c=a**b
print("POWER OF:",c)
# Out:
# ADDITION: 5
# SUBTRACTION: 1
# MULTIPLICATION: 6
# DIVISION: 1.5
# FLOOR DIVISION: 1
# MODULUS: 1
# POWER OF: 9

# %%
a=int(input("ENETR THE VALUE OF a:"))
b=int(input("ENTER THE VALUE OF b:"))
c=a/b
print(c)

# %% [markdown]
# 1.WAP TO FIND OUT THE ROOTS OF A QUADRATIC EQUATION.
